# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 584

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print('Beginning Data Retrieval \n-----------------------------')
record = 1
set = 1

#list to hold response
City = []
Cloudiness = [] 
Country = []   
Date = []      
Humidity = []  
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

#https://pypi.org/project/openweathermapy/ 
# >>> settings = {"units": "metric", "lang": "DE"}
# >>> data = owm.get_current("Kassel,DE", **settings)

settings = {'units': 'Imperial', 'appid':api_key}
#weather = owm.get_current(city, **settings)

for city in cities:
    try:
        weather = owm.get_current(city, **settings)
        print(f"Processing Record {record} of Set {set} | {city}")
        
        City.append(city)
        Cloudiness.append(weather['clouds']['all'])
        Country.append(weather['sys']['country']) 
        Date.append(weather['dt'])      
        Humidity.append(weather['main']['humidity']) 
        Lat.append(weather['coord']['lat']) 
        Lng.append(weather['coord']['lon'])
        Max_Temp.append(weather['main']['temp_max'])
        Wind_Speed.append(weather['wind']['speed'])
        record = record +1
        
    except: 
        print("City not found. Skipping...")
 #50 per set 
    if record == 51:
        record = 0
        set = set + 1
#---------------------------------------------    
# {"coord": { "lon": 139,"lat": 35},
#   "weather": [
#     {
#       "id": 800,
#       "main": "Clear",
#       "description": "clear sky",
#       "icon": "01n"
#     }
#   ],
#   "base": "stations",
#   "main": {
#     "temp": 289.92,
#     "pressure": 1009,
#     "humidity": 92,
#     "temp_min": 288.71,
#     "temp_max": 290.93
#   },
#   "wind": {
#     "speed": 0.47,
#     "deg": 107.538
#   },
#   "clouds": {
#     "all": 2
#   },
#   "dt": 1560350192,
#   "sys": {
#     "type": 3,
#     "id": 2019346,
#     "message": 0.0065,
#     "country": "JP",
#     "sunrise": 1560281377,
#     "sunset": 1560333478
#   },
#   "timezone": 32400,
#   "id": 1851632,
#   "name": "Shuzenji",
#   "cod": 200
# }

print('-----------------------------\nData Retrieval Completed\n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | lipari
# City not found. Skipping...
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | parrita
# Processing Record 8 of Set 1 | rancho palos verdes
# Processing Record 9 of Set 1 | eyrarbakki
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | pavlodar
# Processing Record 14 of Set 1 | altamira
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | hofn
# Processing Record 18 of Set 1 | havelock
# City not found. Skipping...
# Processing Record 19 of Set 1 | shieli
# Processing Record 20 of Set 1 | naryan-mar
# Processing Record 21 of Set 1 | aswan
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | shingu
# Processing Record 24 of Set 1 | arlit
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | conneaut
# City not found. Skipping...
# Processing Record 29 of Set 1 | salinopolis
# Processing Record 30 of Set 1 | guerrero negro
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | hambantota
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | gat
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | san patricio
# Processing Record 39 of Set 1 | artyom
# Processing Record 40 of Set 1 | black diamond
# Processing Record 41 of Set 1 | ferrol
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | canmore
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | kahului
# Processing Record 0 of Set 2 | meulaboh
# Processing Record 1 of Set 2 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | san cristobal
# Processing Record 4 of Set 2 | bathsheba
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | sao felix do xingu
# City not found. Skipping...
# Processing Record 7 of Set 2 | phulabani
# Processing Record 8 of Set 2 | pisco
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 2 | agadez
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | portland
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | brusque
# Processing Record 15 of Set 2 | farafangana
# Processing Record 16 of Set 2 | zhenlai
# Processing Record 17 of Set 2 | zlocieniec
# Processing Record 18 of Set 2 | kosh-agach
# City not found. Skipping...
# Processing Record 19 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | hasaki
# City not found. Skipping...
# Processing Record 23 of Set 2 | coihaique
# Processing Record 24 of Set 2 | mehamn
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | lerwick
# Processing Record 27 of Set 2 | tasiilaq
# City not found. Skipping...
# Processing Record 28 of Set 2 | batticaloa
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | itupiranga
# Processing Record 31 of Set 2 | morondava
# City not found. Skipping...
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | narino
# Processing Record 36 of Set 2 | chakulia
# Processing Record 37 of Set 2 | miranda de ebro
# Processing Record 38 of Set 2 | fairbanks
# Processing Record 39 of Set 2 | salamiyah
# Processing Record 40 of Set 2 | gambela
# Processing Record 41 of Set 2 | severo-yeniseyskiy
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | naduvattam
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | waipawa
# Processing Record 46 of Set 2 | voyvozh
# Processing Record 47 of Set 2 | moose factory
# Processing Record 48 of Set 2 | raudeberg
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | mahebourg
# Processing Record 0 of Set 3 | la puebla del rio
# Processing Record 1 of Set 3 | sept-iles
# Processing Record 2 of Set 3 | yulara
# Processing Record 3 of Set 3 | cidreira
# City not found. Skipping...
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | vengerovo
# Processing Record 6 of Set 3 | oxford
# Processing Record 7 of Set 3 | qandala
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | zhangjiakou
# Processing Record 10 of Set 3 | bam
# Processing Record 11 of Set 3 | baykit
# Processing Record 12 of Set 3 | mnogovershinnyy
# Processing Record 13 of Set 3 | khatanga
# City not found. Skipping...
# Processing Record 14 of Set 3 | pangnirtung
# Processing Record 15 of Set 3 | sibu
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | shebunino
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | nara
# Processing Record 21 of Set 3 | fort-shevchenko
# Processing Record 22 of Set 3 | najran
# Processing Record 23 of Set 3 | swansea
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | tuim
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | chalus
# Processing Record 28 of Set 3 | taoudenni
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | sibolga
# Processing Record 31 of Set 3 | kalmunai
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | santo antonio do ica
# Processing Record 34 of Set 3 | tabou
# Processing Record 35 of Set 3 | leh
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | san rafael
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | san quintin
# Processing Record 41 of Set 3 | vao
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | sao raimundo das mangabeiras
# Processing Record 44 of Set 3 | buin
# Processing Record 45 of Set 3 | pangody
# Processing Record 46 of Set 3 | imbituba
# Processing Record 47 of Set 3 | batagay
# Processing Record 48 of Set 3 | buala
# Processing Record 49 of Set 3 | acari
# Processing Record 50 of Set 3 | chuy
# Processing Record 0 of Set 4 | behbahan
# Processing Record 1 of Set 4 | atambua
# Processing Record 2 of Set 4 | srednekolymsk
# Processing Record 3 of Set 4 | lagoa
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | northampton
# Processing Record 6 of Set 4 | lompoc
# Processing Record 7 of Set 4 | abha
# Processing Record 8 of Set 4 | praia da vitoria
# Processing Record 9 of Set 4 | truckee
# City not found. Skipping...
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | sorland
# Processing Record 12 of Set 4 | toora-khem
# Processing Record 13 of Set 4 | namibe
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | morgan city
# Processing Record 16 of Set 4 | caravelas
# City not found. Skipping...
# Processing Record 17 of Set 4 | port blair
# Processing Record 18 of Set 4 | alexandria
# Processing Record 19 of Set 4 | fukue
# City not found. Skipping...
# Processing Record 20 of Set 4 | san luis
# Processing Record 21 of Set 4 | la palma
# City not found. Skipping...
# Processing Record 22 of Set 4 | dasoguz
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | samarai
# Processing Record 25 of Set 4 | vostok
# City not found. Skipping...
# Processing Record 26 of Set 4 | bianzhuang
# Processing Record 27 of Set 4 | lasa
# Processing Record 28 of Set 4 | bud
# City not found. Skipping...
# Processing Record 29 of Set 4 | cam ranh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 4 | kavieng
# Processing Record 31 of Set 4 | erzin
# Processing Record 32 of Set 4 | eirunepe
# Processing Record 33 of Set 4 | achern
# Processing Record 34 of Set 4 | chebsara
# Processing Record 35 of Set 4 | rochester
# Processing Record 36 of Set 4 | dingle
# Processing Record 37 of Set 4 | camacha
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | dudinka
# Processing Record 40 of Set 4 | adelaide
# Processing Record 41 of Set 4 | iqaluit
# Processing Record 42 of Set 4 | ostrovnoy
# Processing Record 43 of Set 4 | sao filipe
# Processing Record 44 of Set 4 | gizo
# Processing Record 45 of Set 4 | shahpur
# Processing Record 46 of Set 4 | kurikka
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | amga
# Processing Record 49 of Set 4 | atar
# Processing Record 50 of Set 4 | enshi
# City not found. Skipping...
# Processing Record 0 of Set 5 | laguna
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | lukovetskiy
# Processing Record 3 of Set 5 | henties bay
# Processing Record 4 of Set 5 | ewa beach
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | benghazi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 5 | prince rupert
# Processing Record 8 of Set 5 | barcelona
# Processing Record 9 of Set 5 | kudat
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | gamba
# Processing Record 12 of Set 5 | hobyo
# Processing Record 13 of Set 5 | broome
# City not found. Skipping...
# Processing Record 14 of Set 5 | portoferraio
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | tromso
# Processing Record 17 of Set 5 | cabo san lucas
# Processing Record 18 of Set 5 | dikson
# Processing Record 19 of Set 5 | krivosheino
# Processing Record 20 of Set 5 | aksu
# Processing Record 21 of Set 5 | ahuimanu
# City not found. Skipping...
# Processing Record 22 of Set 5 | grand forks
# City not found. Skipping...
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | provideniya
# Processing Record 25 of Set 5 | tautira
# Processing Record 26 of Set 5 | marzuq
# Processing Record 27 of Set 5 | nantucket
# Processing Record 28 of Set 5 | aksarka
# Processing Record 29 of Set 5 | guarapari
# Processing Record 30 of Set 5 | llangefni
# Processing Record 31 of Set 5 | lavrentiya
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | kodinsk
# Processing Record 34 of Set 5 | jonkoping
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | sioux lookout
# Processing Record 37 of Set 5 | souillac
# Processing Record 38 of Set 5 | xinzhou
# City not found. Skipping...
# Processing Record 39 of Set 5 | usakos
# Processing Record 40 of Set 5 | the pas
# Processing Record 41 of Set 5 | sinnamary
# Processing Record 42 of Set 5 | poli
# Processing Record 43 of Set 5 | ornskoldsvik
# Processing Record 44 of Set 5 | dargaville
# Processing Record 45 of Set 5 | rocha
# Processing Record 46 of Set 5 | saint george
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | yara
# Processing Record 49 of Set 5 | kawalu
# Processing Record 50 of Set 5 | flin flon
# Processing Record 0 of Set 6 | constitucion
# Processing Record 1 of Set 6 | marawi
# Processing Record 2 of Set 6 | boa vista
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | pacific grove
# Processing Record 5 of Set 6 | hillsborough
# City not found. Skipping...
# Processing Record 6 of Set 6 | conakry
# Processing Record 7 of Set 6 | iralaya
# Processing Record 8 of Set 6 | werda
# Processing Record 9 of Set 6 | paamiut
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | chandler
# City not found. Skipping...
# Processing Record 12 of Set 6 | inverness
# Processing Record 13 of Set 6 | bambanglipuro
# Processing Record 14 of Set 6 | itoman
# Processing Record 15 of Set 6 | george
# Processing Record 16 of Set 6 | krasnoborsk
# Processing Record 17 of Set 6 | roma
# Processing Record 18 of Set 6 | nyurba
# Processing Record 19 of Set 6 | kaitangata
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | tual
# Processing Record 23 of Set 6 | marsh harbour
# Processing Record 24 of Set 6 | dover
# Processing Record 25 of Set 6 | amapa
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | tateyama
# Processing Record 28 of Set 6 | iracoubo
# Processing Record 29 of Set 6 | hachinohe
# Processing Record 30 of Set 6 | galle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 6 | izumo
# Processing Record 32 of Set 6 | alofi
# Processing Record 33 of Set 6 | katobu
# Processing Record 34 of Set 6 | faanui
# Processing Record 35 of Set 6 | puerto leguizamo
# Processing Record 36 of Set 6 | talas
# Processing Record 37 of Set 6 | kailua
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | vancouver
# Processing Record 40 of Set 6 | norman wells
# Processing Record 41 of Set 6 | saint-joseph
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | san angelo
# Processing Record 44 of Set 6 | rovnoye
# Processing Record 45 of Set 6 | sapulpa
# Processing Record 46 of Set 6 | leesburg
# Processing Record 47 of Set 6 | aginskoye
# City not found. Skipping...
# Processing Record 48 of Set 6 | leningradskiy
# Processing Record 49 of Set 6 | mwingi
# Processing Record 50 of Set 6 | puerto del rosario
# Processing Record 0 of Set 7 | longyearbyen
# Processing Record 1 of Set 7 | broken hill
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | omboue
# Processing Record 4 of Set 7 | megion
# City not found. Skipping...
# Processing Record 5 of Set 7 | egvekinot
# Processing Record 6 of Set 7 | aldan
# Processing Record 7 of Set 7 | dingzhou
# Processing Record 8 of Set 7 | dakoro
# Processing Record 9 of Set 7 | elizabeth city
# Processing Record 10 of Set 7 | pevek
# Processing Record 11 of Set 7 | jacareacanga
# Processing Record 12 of Set 7 | araceli
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | missoula
# Processing Record 15 of Set 7 | dalmatovo
# Processing Record 16 of Set 7 | soto
# City not found. Skipping...
# Processing Record 17 of Set 7 | ridgecrest
# Processing Record 18 of Set 7 | esna
# Processing Record 19 of Set 7 | mount isa
# Processing Record 20 of Set 7 | ostersund
# City not found. Skipping...
# Processing Record 21 of Set 7 | ixtapa
# Processing Record 22 of Set 7 | koumac
# Processing Record 23 of Set 7 | camrose
# Processing Record 24 of Set 7 | heihe
# Processing Record 25 of Set 7 | komsomolskiy
# Processing Record 26 of Set 7 | merauke
# Processing Record 27 of Set 7 | karpathos
# Processing Record 28 of Set 7 | pyshma
# Processing Record 29 of Set 7 | catuday
# Processing Record 30 of Set 7 | lima
# Processing Record 31 of Set 7 | colac
# Processing Record 32 of Set 7 | svetlogorsk
# Processing Record 33 of Set 7 | kibala
# Processing Record 34 of Set 7 | tura
# Processing Record 35 of Set 7 | takoradi
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | athens
# Processing Record 38 of Set 7 | gondanglegi
# City not found. Skipping...
# Processing Record 39 of Set 7 | rio grande
# City not found. Skipping...
# Processing Record 40 of Set 7 | kudahuvadhoo
# Processing Record 41 of Set 7 | picota
# Processing Record 42 of Set 7 | gaoual
# Processing Record 43 of Set 7 | maniitsoq
# Processing Record 44 of Set 7 | port hedland
# Processing Record 45 of Set 7 | lakes entrance
# Processing Record 46 of Set 7 | pimentel
# Processing Record 47 of Set 7 | ojinaga
# City not found. Skipping...
# Processing Record 48 of Set 7 | havoysund
# Processing Record 49 of Set 7 | seydi
# Processing Record 50 of Set 7 | vanavara
# Processing Record 0 of Set 8 | barcelos
# Processing Record 1 of Set 8 | san andres
# Processing Record 2 of Set 8 | tecoanapa
# Processing Record 3 of Set 8 | soledade
# Processing Record 4 of Set 8 | san rafael del sur
# Processing Record 5 of Set 8 | maceio
# Processing Record 6 of Set 8 | oytal
# Processing Record 7 of Set 8 | pathein
# Processing Record 8 of Set 8 | cockburn town
# Processing Record 9 of Set 8 | port macquarie
# Processing Record 10 of Set 8 | san carlos
# Processing Record 11 of Set 8 | gap
# City not found. Skipping...
# Processing Record 12 of Set 8 | alice springs
# Processing Record 13 of Set 8 | usinsk
# Processing Record 14 of Set 8 | zyryanovsk
# Processing Record 15 of Set 8 | los llanos de aridane
# Processing Record 16 of Set 8 | isangel
# City not found. Skipping...
# Processing Record 17 of Set 8 | napasar
# Processing Record 18 of Set 8 | lang suan
# Processing Record 19 of Set 8 | limoges
# Processing Record 20 of Set 8 | sobolevo
# Processing Record 21 of Set 8 | rio verde de mato grosso
# Processing Record 22 of Set 8 | digby
# Processing Record 23 of Set 8 | port said
# Processing Record 24 of Set 8 | baruun-urt
# Processing Record 25 of Set 8 | terrace bay
# Processing Record 26 of Set 8 | isabela
# Processing Record 27 of Set 8 | sabha
# Processing Record 28 of Set 8 | ust-nera
# Processing Record 29 of Set 8 | kieta
# Processing Record 30 of Set 8 | paracuru
# Processing Record 31 of Set 8 | jennings
# Processing Record 32 of Set 8 | murdochville
# Processing Record 33 of Set 8 | nouadhibou
# Processing Record 34 of Set 8 | tucuman
# Processing Record 35 of Set 8 | risor
# Processing Record 36 of Set 8 | maumere
# Processing Record 37 of Set 8 | yar-sale
# Processing Record 38 of Set 8 | marienburg
# Processing Record 39 of Set 8 | chipinge
# Processing Record 40 of Set 8 | belaya gora
# City not found. Skipping...
# Processing Record 41 of Set 8 | smithers
# Processing Record 42 of Set 8 | mayo
# Processing Record 43 of Set 8 | thompson
# Processing Record 44 of Set 8 | nuuk
# Processing Record 45 of Set 8 | yarmouth
# Processing Record 46 of Set 8 | moerai
# Processing Record 47 of Set 8 | pokosnoye
# Processing Record 48 of Set 8 | udachnyy
# City not found. Skipping...
# Processing Record 49 of Set 8 | kiruna
# Processing Record 50 of Set 8 | ponta delgada
# Processing Record 0 of Set 9 | zyryanka
# Processing Record 1 of Set 9 | lardos
# Processing Record 2 of Set 9 | ilulissat
# Processing Record 3 of Set 9 | yinchuan
# Processing Record 4 of Set 9 | aklavik
# Processing Record 5 of Set 9 | beringovskiy
# Processing Record 6 of Set 9 | concepcion
# Processing Record 7 of Set 9 | doha
# Processing Record 8 of Set 9 | wainwright
# Processing Record 9 of Set 9 | daru
# Processing Record 10 of Set 9 | biloela
# Processing Record 11 of Set 9 | fort nelson
# Processing Record 12 of Set 9 | monterey
# Processing Record 13 of Set 9 | beisfjord
# City not found. Skipping...
# Processing Record 14 of Set 9 | san fernando
# Processing Record 15 of Set 9 | lieksa
# Processing Record 16 of Set 9 | moju
# Processing Record 17 of Set 9 | carnarvon
# Processing Record 18 of Set 9 | sorsk
# Processing Record 19 of Set 9 | tadpatri
# Processing Record 20 of Set 9 | teacapan
# City not found. Skipping...
# Processing Record 21 of Set 9 | tucumcari
# Processing Record 22 of Set 9 | luganville
# Processing Record 23 of Set 9 | charleston
# Processing Record 24 of Set 9 | tsabong
# Processing Record 25 of Set 9 | chaumont
# Processing Record 26 of Set 9 | sidney
# Processing Record 27 of Set 9 | ballina
# Processing Record 28 of Set 9 | lola
# City not found. Skipping...
# Processing Record 29 of Set 9 | gouyave
# Processing Record 30 of Set 9 | les cayes
# Processing Record 31 of Set 9 | baoro
# Processing Record 32 of Set 9 | khasan
# Processing Record 33 of Set 9 | soto la marina
# Processing Record 34 of Set 9 | bilma
# Processing Record 35 of Set 9 | suluq
# Processing Record 36 of Set 9 | trincomalee
# City not found. Skipping...
# Processing Record 37 of Set 9 | cherskiy
# Processing Record 38 of Set 9 | andapa
# Processing Record 39 of Set 9 | pelotas
# Processing Record 40 of Set 9 | parabel
# Processing Record 41 of Set 9 | vaitape
# City not found. Skipping...
# Processing Record 42 of Set 9 | audru
# Processing Record 43 of Set 9 | dicabisagan
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | sheboygan
# Processing Record 46 of Set 9 | sechura
# Processing Record 47 of Set 9 | cheremukhovo
# Processing Record 48 of Set 9 | la rioja
# Processing Record 49 of Set 9 | winchester
# Processing Record 50 of Set 9 | padang
# Processing Record 0 of Set 10 | morant bay
# Processing Record 1 of Set 10 | wajir
# Processing Record 2 of Set 10 | amahai
# Processing Record 3 of Set 10 | hailar
# Processing Record 4 of Set 10 | eenhana
# Processing Record 5 of Set 10 | okha
# Processing Record 6 of Set 10 | pasni
# Processing Record 7 of Set 10 | cap malheureux
# Processing Record 8 of Set 10 | banda aceh
# Processing Record 9 of Set 10 | whitehorse
# Processing Record 10 of Set 10 | arona
# Processing Record 11 of Set 10 | pringsewu
# Processing Record 12 of Set 10 | emirdag
# Processing Record 13 of Set 10 | kulhudhuffushi
# Processing Record 14 of Set 10 | suraabad
# Processing Record 15 of Set 10 | auki
# City not found. Skipping...
# Processing Record 16 of Set 10 | debre tabor
# Processing Record 17 of Set 10 | northam
# Processing Record 18 of Set 10 | coquimbo
# City not found. Skipping...
# Processing Record 19 of Set 10 | woodward
# Processing Record 20 of Set 10 | novaya ladoga
# Processing Record 21 of Set 10 | cayenne
# Processing Record 22 of Set 10 | palmer
# Processing Record 23 of Set 10 | santa rosa
# Processing Record 24 of Set 10 | burns lake
# Processing Record 25 of Set 10 | grand-bourg
# City not found. Skipping...
# Processing Record 26 of Set 10 | codrington
# Processing Record 27 of Set 10 | matagami
# Processing Record 28 of Set 10 | kysyl-syr
# Processing Record 29 of Set 10 | kupang
# Processing Record 30 of Set 10 | nabire
# Processing Record 31 of Set 10 | hirara
# Processing Record 32 of Set 10 | kuusamo
# Processing Record 33 of Set 10 | herveo
# Processing Record 34 of Set 10 | luanda
# Processing Record 35 of Set 10 | ambovombe
# City not found. Skipping...
# Processing Record 36 of Set 10 | north bend
# Processing Record 37 of Set 10 | santiago del estero
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 10 | terra santa
# Processing Record 39 of Set 10 | san carlos de bariloche
# Processing Record 40 of Set 10 | maralal
# Processing Record 41 of Set 10 | dabakala
# Processing Record 42 of Set 10 | sturgis
# Processing Record 43 of Set 10 | gobabis
# Processing Record 44 of Set 10 | curumani
# Processing Record 45 of Set 10 | akdepe
# City not found. Skipping...
# Processing Record 46 of Set 10 | bukachacha
# Processing Record 47 of Set 10 | madera
# Processing Record 48 of Set 10 | necochea
# City not found. Skipping...
# Processing Record 49 of Set 10 | bolshevik
# Processing Record 50 of Set 10 | tairua
# City not found. Skipping...
# Processing Record 0 of Set 11 | hualmay
# Processing Record 1 of Set 11 | elat
# City not found. Skipping...
# Processing Record 2 of Set 11 | ko samui
# Processing Record 3 of Set 11 | valadares
# Processing Record 4 of Set 11 | nhamunda
# Processing Record 5 of Set 11 | concarneau
# Processing Record 6 of Set 11 | hervey bay
# City not found. Skipping...
# Processing Record 7 of Set 11 | bagdarin
# Processing Record 8 of Set 11 | shimoda
# Processing Record 9 of Set 11 | kirkwall
# Processing Record 10 of Set 11 | avera
# -----------------------------
# Data Retrieval Completed
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({'City': City,
                          'Cloudiness': Cloudiness,
                           'Country': Country,
                           'Date': Date,
                           'Humidity':Humidity,
                           'Lat':Lat,
                           'Lng': Lng,
                           'Max Temp': Max_Temp,
                           'Wind Speed': Wind_Speed
                          })
weather_df.count()
# Out:
# City          520
# Cloudiness    520
# Country       520
# Date          520
# Humidity      520
# Lat           520
# Lng           520
# Max Temp      520
# Wind Speed    520
# dtype: int64

# %%
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            tiksi          92      RU  1561659214        79  71.64  128.87
# 1      new norfolk           0      AU  1561658979        62 -42.78  147.06
# 2   ribeira grande          40      PT  1561659215        60  38.52  -28.70
# 3  arraial do cabo          20      BR  1561659215        78 -22.97  -42.02
# 4           lipari          40      IT  1561659215        74  38.47   14.95
#
#    Max Temp  Wind Speed
# 0     45.85       11.83
# 1     57.00        9.17
# 2     68.00       11.41
# 3     80.60        9.17
# 4     84.99        6.93

# %%
#UTC time to local time
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.htmldf['timestamp'].dt.tz_localize('utc').dt.tz_convert('US/Central')
#EX:    pd.to_datetime(1490195805, unit='s') <---- Timestamp('2017-03-22 15:16:45')

Date = pd.to_datetime(1561615905, unit='s')
Date
# Out:
# Timestamp('2019-06-27 06:11:45')

# %%
#save to csv
weather_df.to_csv('output_data/weather_pd.csv', index = False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plot Latitude vs. Temperature
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Max Temperature (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Max Temperature(F)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_MaxTemp", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plot Latitude vs. Humidity
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Humidity (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Humidity (%)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_Humidity", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plot Latitude vs. Cloudiness
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Cloudiness (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Cloudiness (%)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_Cloudiness", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plot Latitude vs. Wind Speed
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Wind Speed (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Wind Speed (mph)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_WindSpeed", bbox_inches='tight')
plt.show()
