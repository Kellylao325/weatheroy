# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print('Beginning Data Retrieval \n-----------------------------')
record = 1
set = 1

#list to hold response
City = []
Cloudiness = [] 
Country = []   
Date = []      
Humidity = []  
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

#https://pypi.org/project/openweathermapy/ 
# >>> settings = {"units": "metric", "lang": "DE"}
# >>> data = owm.get_current("Kassel,DE", **settings)

settings = {'units': 'Imperial', 'appid':api_key}
#weather = owm.get_current(city, **settings)

for city in cities:
    try:
        weather = owm.get_current(city, **settings)
        print(f"Processing Record {record} of Set {set} | {city}")
        
        City.append(city)
        Cloudiness.append(weather['clouds']['all'])
        Country.append(weather['sys']['country']) 
        Date.append(weather['dt'])      
        Humidity.append(weather['main']['humidity']) 
        Lat.append(weather['coord']['lat']) 
        Lng.append(weather['coord']['lon'])
        Max_Temp.append(weather['main']['temp_max'])
        Wind_Speed.append(weather['wind']['speed'])
        record = record +1
        
    except: 
        print("City not found. Skipping...")
 #50 per set 
    if record == 51:
        record = 0
        set = set + 1
#---------------------------------------------    
# {"coord": { "lon": 139,"lat": 35},
#   "weather": [
#     {
#       "id": 800,
#       "main": "Clear",
#       "description": "clear sky",
#       "icon": "01n"
#     }
#   ],
#   "base": "stations",
#   "main": {
#     "temp": 289.92,
#     "pressure": 1009,
#     "humidity": 92,
#     "temp_min": 288.71,
#     "temp_max": 290.93
#   },
#   "wind": {
#     "speed": 0.47,
#     "deg": 107.538
#   },
#   "clouds": {
#     "all": 2
#   },
#   "dt": 1560350192,
#   "sys": {
#     "type": 3,
#     "id": 2019346,
#     "message": 0.0065,
#     "country": "JP",
#     "sunrise": 1560281377,
#     "sunset": 1560333478
#   },
#   "timezone": 32400,
#   "id": 1851632,
#   "name": "Shuzenji",
#   "cod": 200
# }

print('-----------------------------\nData Retrieval Completed\n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sabang
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | inhambane
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | the valley
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | mao
# City not found. Skipping...
# Processing Record 10 of Set 1 | pangnirtung
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | ossora
# Processing Record 14 of Set 1 | tripoli
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | pasighat
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | kitimat
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | cubara
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | agadir
# Processing Record 24 of Set 1 | ruteng
# City not found. Skipping...
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | tateyama
# City not found. Skipping...
# Processing Record 28 of Set 1 | palu
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | raikot
# Processing Record 31 of Set 1 | dashitou
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | paamiut
# Processing Record 35 of Set 1 | egvekinot
# Processing Record 36 of Set 1 | vestmannaeyjar
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | matucana
# City not found. Skipping...
# Processing Record 42 of Set 1 | moron
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | lasa
# Processing Record 46 of Set 1 | port hawkesbury
# Processing Record 47 of Set 1 | almaznyy
# Processing Record 48 of Set 1 | sri aman
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | saskylakh
# City not found. Skipping...
# Processing Record 0 of Set 2 | acajutla
# Processing Record 1 of Set 2 | nantucket
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | san ramon
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | touros
# City not found. Skipping...
# Processing Record 6 of Set 2 | kambove
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | kruisfontein
# City not found. Skipping...
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | bathsheba
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | padang
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | rawicz
# City not found. Skipping...
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | verkhnyaya inta
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | susanville
# Processing Record 27 of Set 2 | bubaque
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | port blair
# Processing Record 30 of Set 2 | monte patria
# Processing Record 31 of Set 2 | esso
# Processing Record 32 of Set 2 | vestmanna
# Processing Record 33 of Set 2 | isangel
# City not found. Skipping...
# Processing Record 34 of Set 2 | najran
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | oktyabrskoye
# Processing Record 38 of Set 2 | warrnambool
# Processing Record 39 of Set 2 | ocean springs
# Processing Record 40 of Set 2 | vitim
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | mount isa
# Processing Record 43 of Set 2 | christchurch
# Processing Record 44 of Set 2 | ilhabela
# Processing Record 45 of Set 2 | lac du bonnet
# Processing Record 46 of Set 2 | praia da vitoria
# Processing Record 47 of Set 2 | appleton
# City not found. Skipping...
# Processing Record 48 of Set 2 | calabozo
# Processing Record 49 of Set 2 | caravelas
# Processing Record 50 of Set 2 | oriximina
# Processing Record 0 of Set 3 | sobolevo
# Processing Record 1 of Set 3 | thessalon
# Processing Record 2 of Set 3 | nenjiang
# Processing Record 3 of Set 3 | saint-francois
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | polis
# Processing Record 7 of Set 3 | trat
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | porto novo
# Processing Record 10 of Set 3 | adrar
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | morgan city
# Processing Record 13 of Set 3 | road town
# City not found. Skipping...
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | merauke
# Processing Record 16 of Set 3 | wattegama
# Processing Record 17 of Set 3 | northam
# Processing Record 18 of Set 3 | baykit
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | mokrousovo
# Processing Record 21 of Set 3 | ankara
# Processing Record 22 of Set 3 | ratnagiri
# Processing Record 23 of Set 3 | preston
# Processing Record 24 of Set 3 | lodja
# Processing Record 25 of Set 3 | svetlaya
# Processing Record 26 of Set 3 | jonesboro
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | kampot
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | newport
# Processing Record 32 of Set 3 | telimele
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | santa flavia
# Processing Record 35 of Set 3 | vostok
# Processing Record 36 of Set 3 | kalino
# Processing Record 37 of Set 3 | pevek
# Processing Record 38 of Set 3 | lincoln
# Processing Record 39 of Set 3 | wiarton
# Processing Record 40 of Set 3 | ust-ilimsk
# City not found. Skipping...
# Processing Record 41 of Set 3 | nouadhibou
# Processing Record 42 of Set 3 | takoradi
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | constitucion
# Processing Record 45 of Set 3 | kasongo-lunda
# Processing Record 46 of Set 3 | pacific grove
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | nemuro
# Processing Record 50 of Set 3 | dingle
# Processing Record 0 of Set 4 | grand gaube
# Processing Record 1 of Set 4 | estacion coahuila
# City not found. Skipping...
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | san javier
# Processing Record 6 of Set 4 | bratsk
# Processing Record 7 of Set 4 | farah
# Processing Record 8 of Set 4 | guacimo
# Processing Record 9 of Set 4 | eyl
# Processing Record 10 of Set 4 | tashtagol
# Processing Record 11 of Set 4 | lewiston
# City not found. Skipping...
# Processing Record 12 of Set 4 | oranjemund
# City not found. Skipping...
# Processing Record 13 of Set 4 | sijunjung
# Processing Record 14 of Set 4 | huarmey
# Processing Record 15 of Set 4 | taybad
# Processing Record 16 of Set 4 | matara
# Processing Record 17 of Set 4 | tuusula
# Processing Record 18 of Set 4 | naze
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | nikolskoye
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | cape town
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | khani
# Processing Record 26 of Set 4 | basco
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | noumea
# Processing Record 30 of Set 4 | sarai
# City not found. Skipping...
# Processing Record 31 of Set 4 | pedra branca
# Processing Record 32 of Set 4 | madaras
# Processing Record 33 of Set 4 | moanda
# Processing Record 34 of Set 4 | kununurra
# Processing Record 35 of Set 4 | halifax
# Processing Record 36 of Set 4 | yar-sale
# Processing Record 37 of Set 4 | saint anthony
# Processing Record 38 of Set 4 | lagoa
# Processing Record 39 of Set 4 | manokwari
# Processing Record 40 of Set 4 | chipoka
# Processing Record 41 of Set 4 | airai
# City not found. Skipping...
# Processing Record 42 of Set 4 | tahoua
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 4 | shimoda
# Processing Record 44 of Set 4 | manacapuru
# Processing Record 45 of Set 4 | talnakh
# Processing Record 46 of Set 4 | henties bay
# Processing Record 47 of Set 4 | hasaki
# City not found. Skipping...
# Processing Record 48 of Set 4 | aloleng
# Processing Record 49 of Set 4 | fort nelson
# Processing Record 50 of Set 4 | dunedin
# Processing Record 0 of Set 5 | san cristobal
# Processing Record 1 of Set 5 | askino
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | altamont
# Processing Record 4 of Set 5 | mufulira
# Processing Record 5 of Set 5 | nieuw amsterdam
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | akdepe
# Processing Record 8 of Set 5 | roebourne
# City not found. Skipping...
# Processing Record 9 of Set 5 | vardo
# Processing Record 10 of Set 5 | beaverlodge
# Processing Record 11 of Set 5 | tautira
# Processing Record 12 of Set 5 | kaka
# City not found. Skipping...
# Processing Record 13 of Set 5 | mahajanga
# Processing Record 14 of Set 5 | pontes e lacerda
# Processing Record 15 of Set 5 | bandarbeyla
# Processing Record 16 of Set 5 | sangueya
# Processing Record 17 of Set 5 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 18 of Set 5 | juneau
# Processing Record 19 of Set 5 | tanout
# Processing Record 20 of Set 5 | awjilah
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | teguldet
# Processing Record 23 of Set 5 | klamath falls
# Processing Record 24 of Set 5 | coihaique
# Processing Record 25 of Set 5 | koulamoutou
# Processing Record 26 of Set 5 | kaeo
# Processing Record 27 of Set 5 | mendrisio
# City not found. Skipping...
# Processing Record 28 of Set 5 | santa maria da vitoria
# Processing Record 29 of Set 5 | jacala
# Processing Record 30 of Set 5 | aswan
# Processing Record 31 of Set 5 | westport
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | le port
# Processing Record 34 of Set 5 | viseu
# Processing Record 35 of Set 5 | baraki barak
# Processing Record 36 of Set 5 | ligayan
# Processing Record 37 of Set 5 | quang ngai
# Processing Record 38 of Set 5 | balkanabat
# Processing Record 39 of Set 5 | longjiang
# Processing Record 40 of Set 5 | marsh harbour
# City not found. Skipping...
# Processing Record 41 of Set 5 | jacmel
# City not found. Skipping...
# Processing Record 42 of Set 5 | talaya
# Processing Record 43 of Set 5 | soe
# Processing Record 44 of Set 5 | umm kaddadah
# Processing Record 45 of Set 5 | lumeje
# Processing Record 46 of Set 5 | sunland park
# Processing Record 47 of Set 5 | karpathos
# Processing Record 48 of Set 5 | miami
# Processing Record 49 of Set 5 | yushan
# Processing Record 50 of Set 5 | asadabad
# Processing Record 0 of Set 6 | pangkalanbuun
# Processing Record 1 of Set 6 | bajil
# Processing Record 2 of Set 6 | pangody
# Processing Record 3 of Set 6 | codrington
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 6 | la macarena
# Processing Record 5 of Set 6 | awbari
# Processing Record 6 of Set 6 | college
# Processing Record 7 of Set 6 | wangkui
# Processing Record 8 of Set 6 | lethem
# City not found. Skipping...
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | san andres
# Processing Record 11 of Set 6 | la ronge
# Processing Record 12 of Set 6 | shieli
# Processing Record 13 of Set 6 | bonfim
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | kaura namoda
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | rocha
# City not found. Skipping...
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | kavaratti
# Processing Record 21 of Set 6 | sioux lookout
# City not found. Skipping...
# Processing Record 22 of Set 6 | fernie
# Processing Record 23 of Set 6 | rio brilhante
# Processing Record 24 of Set 6 | sept-iles
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | raudeberg
# City not found. Skipping...
# Processing Record 27 of Set 6 | samarai
# Processing Record 28 of Set 6 | calatayud
# Processing Record 29 of Set 6 | baghmara
# Processing Record 30 of Set 6 | port augusta
# Processing Record 31 of Set 6 | buchanan
# City not found. Skipping...
# Processing Record 32 of Set 6 | namibe
# Processing Record 33 of Set 6 | carlyle
# City not found. Skipping...
# Processing Record 34 of Set 6 | mareeba
# Processing Record 35 of Set 6 | dongsheng
# Processing Record 36 of Set 6 | sulangan
# Processing Record 37 of Set 6 | palmer
# Processing Record 38 of Set 6 | jalu
# City not found. Skipping...
# Processing Record 39 of Set 6 | mandalgovi
# City not found. Skipping...
# Processing Record 40 of Set 6 | te anau
# Processing Record 41 of Set 6 | kadoma
# Processing Record 42 of Set 6 | ivankiv
# Processing Record 43 of Set 6 | tura
# City not found. Skipping...
# Processing Record 44 of Set 6 | sur
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | thinadhoo
# Processing Record 47 of Set 6 | okhotsk
# Processing Record 48 of Set 6 | copiapo
# Processing Record 49 of Set 6 | erie
# Processing Record 50 of Set 6 | bannu
# Processing Record 0 of Set 7 | abalak
# Processing Record 1 of Set 7 | bonthe
# City not found. Skipping...
# Processing Record 2 of Set 7 | espinosa
# Processing Record 3 of Set 7 | kokopo
# Processing Record 4 of Set 7 | berdigestyakh
# Processing Record 5 of Set 7 | zhanaozen
# Processing Record 6 of Set 7 | riyadh
# Processing Record 7 of Set 7 | sokoto
# Processing Record 8 of Set 7 | alice springs
# Processing Record 9 of Set 7 | general roca
# Processing Record 10 of Set 7 | bilibino
# Processing Record 11 of Set 7 | gejiu
# Processing Record 12 of Set 7 | colares
# Processing Record 13 of Set 7 | takapau
# Processing Record 14 of Set 7 | xining
# Processing Record 15 of Set 7 | hambantota
# Processing Record 16 of Set 7 | winnemucca
# Processing Record 17 of Set 7 | allen
# Processing Record 18 of Set 7 | jimenez
# Processing Record 19 of Set 7 | stryn
# City not found. Skipping...
# Processing Record 20 of Set 7 | san luis
# Processing Record 21 of Set 7 | luanda
# Processing Record 22 of Set 7 | sistranda
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | taguatinga
# Processing Record 25 of Set 7 | lompoc
# Processing Record 26 of Set 7 | port hedland
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | kieta
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | canmore
# City not found. Skipping...
# Processing Record 31 of Set 7 | avera
# Processing Record 32 of Set 7 | wuxue
# Processing Record 33 of Set 7 | sorland
# Processing Record 34 of Set 7 | dolores
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | jacareacanga
# Processing Record 37 of Set 7 | prince rupert
# Processing Record 38 of Set 7 | wolgast
# Processing Record 39 of Set 7 | chon buri
# Processing Record 40 of Set 7 | comodoro rivadavia
# Processing Record 41 of Set 7 | angoche
# City not found. Skipping...
# Processing Record 42 of Set 7 | longyan
# Processing Record 43 of Set 7 | bijie
# Processing Record 44 of Set 7 | blackwater
# Processing Record 45 of Set 7 | cuamba
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | puerto narino
# Processing Record 48 of Set 7 | troyes
# Processing Record 49 of Set 7 | villeneuve-sur-lot
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 7 | yuci
# Processing Record 0 of Set 8 | santa catalina
# Processing Record 1 of Set 8 | playa del carmen
# Processing Record 2 of Set 8 | leningradskiy
# Processing Record 3 of Set 8 | labuan
# Processing Record 4 of Set 8 | hofn
# Processing Record 5 of Set 8 | kasongo
# City not found. Skipping...
# Processing Record 6 of Set 8 | antalya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 8 | otane
# Processing Record 8 of Set 8 | san patricio
# Processing Record 9 of Set 8 | zhezkazgan
# Processing Record 10 of Set 8 | ahipara
# Processing Record 11 of Set 8 | santa barbara
# Processing Record 12 of Set 8 | whitehorse
# Processing Record 13 of Set 8 | larsnes
# Processing Record 14 of Set 8 | la carolina
# Processing Record 15 of Set 8 | besikduzu
# Processing Record 16 of Set 8 | brazzaville
# Processing Record 17 of Set 8 | ixtlahuacan del rio
# Processing Record 18 of Set 8 | kirakira
# Processing Record 19 of Set 8 | khorixas
# Processing Record 20 of Set 8 | ati
# Processing Record 21 of Set 8 | cody
# Processing Record 22 of Set 8 | rexburg
# Processing Record 23 of Set 8 | tilichiki
# Processing Record 24 of Set 8 | kletnya
# Processing Record 25 of Set 8 | tirat karmel
# Processing Record 26 of Set 8 | rosarito
# Processing Record 27 of Set 8 | hobyo
# Processing Record 28 of Set 8 | tiksi
# Processing Record 29 of Set 8 | sangar
# Processing Record 30 of Set 8 | katsuura
# Processing Record 31 of Set 8 | lakatoro
# Processing Record 32 of Set 8 | mahon
# Processing Record 33 of Set 8 | madanapalle
# Processing Record 34 of Set 8 | grootfontein
# Processing Record 35 of Set 8 | flin flon
# Processing Record 36 of Set 8 | marsa matruh
# Processing Record 37 of Set 8 | nurota
# Processing Record 38 of Set 8 | otuzco
# City not found. Skipping...
# Processing Record 39 of Set 8 | anito
# Processing Record 40 of Set 8 | ust-tsilma
# Processing Record 41 of Set 8 | ullapool
# Processing Record 42 of Set 8 | lavrentiya
# City not found. Skipping...
# Processing Record 43 of Set 8 | kharagpur
# City not found. Skipping...
# Processing Record 44 of Set 8 | hualmay
# Processing Record 45 of Set 8 | olinda
# City not found. Skipping...
# Processing Record 46 of Set 8 | dwarka
# Processing Record 47 of Set 8 | sunrise manor
# Processing Record 48 of Set 8 | hovd
# Processing Record 49 of Set 8 | basmat
# City not found. Skipping...
# Processing Record 50 of Set 8 | benghazi
# Processing Record 0 of Set 9 | lata
# Processing Record 1 of Set 9 | fare
# Processing Record 2 of Set 9 | wanning
# Processing Record 3 of Set 9 | masvingo
# Processing Record 4 of Set 9 | labuhan
# Processing Record 5 of Set 9 | broome
# Processing Record 6 of Set 9 | tortoli
# Processing Record 7 of Set 9 | soledade
# City not found. Skipping...
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | sorong
# Processing Record 10 of Set 9 | lakes entrance
# Processing Record 11 of Set 9 | lima
# Processing Record 12 of Set 9 | emirdag
# Processing Record 13 of Set 9 | mezhdurechensk
# Processing Record 14 of Set 9 | whyalla
# Processing Record 15 of Set 9 | mponela
# Processing Record 16 of Set 9 | saint-augustin
# Processing Record 17 of Set 9 | tayu
# Processing Record 18 of Set 9 | preobrazheniye
# Processing Record 19 of Set 9 | luderitz
# City not found. Skipping...
# Processing Record 20 of Set 9 | aquiraz
# Processing Record 21 of Set 9 | benguela
# Processing Record 22 of Set 9 | herat
# Processing Record 23 of Set 9 | dudinka
# Processing Record 24 of Set 9 | biograd na moru
# Processing Record 25 of Set 9 | pedernales
# Processing Record 26 of Set 9 | nelson bay
# Processing Record 27 of Set 9 | vila do maio
# Processing Record 28 of Set 9 | pacifica
# Processing Record 29 of Set 9 | bowen
# Processing Record 30 of Set 9 | port keats
# Processing Record 31 of Set 9 | tumut
# City not found. Skipping...
# Processing Record 32 of Set 9 | bauchi
# Processing Record 33 of Set 9 | tocopilla
# Processing Record 34 of Set 9 | catuday
# Processing Record 35 of Set 9 | taitung
# Processing Record 36 of Set 9 | ambon
# Processing Record 37 of Set 9 | mocuba
# Processing Record 38 of Set 9 | alassio
# Processing Record 39 of Set 9 | alabaster
# Processing Record 40 of Set 9 | aykhal
# Processing Record 41 of Set 9 | daigo
# Processing Record 42 of Set 9 | kiunga
# City not found. Skipping...
# Processing Record 43 of Set 9 | itarema
# City not found. Skipping...
# Processing Record 44 of Set 9 | behbahan
# Processing Record 45 of Set 9 | lokoja
# Processing Record 46 of Set 9 | siculeni
# Processing Record 47 of Set 9 | nyuksenitsa
# Processing Record 48 of Set 9 | salym
# Processing Record 49 of Set 9 | nanyang
# Processing Record 50 of Set 9 | kasempa
# Processing Record 0 of Set 10 | bafoulabe
# Processing Record 1 of Set 10 | khorramshahr
# City not found. Skipping...
# Processing Record 2 of Set 10 | antofagasta
# Processing Record 3 of Set 10 | muncar
# Processing Record 4 of Set 10 | mizan teferi
# Processing Record 5 of Set 10 | kodinsk
# Processing Record 6 of Set 10 | severo-kurilsk
# Processing Record 7 of Set 10 | quatre cocos
# Processing Record 8 of Set 10 | ponta delgada
# Processing Record 9 of Set 10 | severnoye
# Processing Record 10 of Set 10 | virginia beach
# Processing Record 11 of Set 10 | kenai
# Processing Record 12 of Set 10 | makat
# City not found. Skipping...
# Processing Record 13 of Set 10 | quelimane
# Processing Record 14 of Set 10 | khovu-aksy
# Processing Record 15 of Set 10 | pikesville
# Processing Record 16 of Set 10 | portales
# Processing Record 17 of Set 10 | liverpool
# Processing Record 18 of Set 10 | tambun
# Processing Record 19 of Set 10 | kahului
# Processing Record 20 of Set 10 | aksarka
# City not found. Skipping...
# Processing Record 21 of Set 10 | qujing
# Processing Record 22 of Set 10 | manicore
# Processing Record 23 of Set 10 | aqtobe
# Processing Record 24 of Set 10 | fauske
# City not found. Skipping...
# Processing Record 25 of Set 10 | scalea
# Processing Record 26 of Set 10 | forio
# Processing Record 27 of Set 10 | leh
# Processing Record 28 of Set 10 | shizunai
# Processing Record 29 of Set 10 | saint marys
# Processing Record 30 of Set 10 | juegang
# City not found. Skipping...
# Processing Record 31 of Set 10 | kargil
# Processing Record 32 of Set 10 | aguimes
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 10 | camapua
# Processing Record 34 of Set 10 | trofors
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | kensington
# Processing Record 37 of Set 10 | kloulklubed
# Processing Record 38 of Set 10 | nuevo progreso
# Processing Record 39 of Set 10 | gravelbourg
# Processing Record 40 of Set 10 | antalaha
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | evensk
# Processing Record 43 of Set 10 | geraldton
# Processing Record 44 of Set 10 | iqaluit
# Processing Record 45 of Set 10 | prince george
# Processing Record 46 of Set 10 | saint-ambroise
# Processing Record 47 of Set 10 | urdoma
# Processing Record 48 of Set 10 | jimo
# Processing Record 49 of Set 10 | puerto escondido
# Processing Record 50 of Set 10 | shahrud
# City not found. Skipping...
# Processing Record 0 of Set 11 | yumen
# Processing Record 1 of Set 11 | boende
# Processing Record 2 of Set 11 | kumluca
# Processing Record 3 of Set 11 | viedma
# Processing Record 4 of Set 11 | yeppoon
# Processing Record 5 of Set 11 | bo rai
# Processing Record 6 of Set 11 | luganville
# Processing Record 7 of Set 11 | sibolga
# Processing Record 8 of Set 11 | ballina
# City not found. Skipping...
# Processing Record 9 of Set 11 | kiama
# Processing Record 10 of Set 11 | cortes
# Processing Record 11 of Set 11 | cidreira
# Processing Record 12 of Set 11 | kingaroy
# Processing Record 13 of Set 11 | tiznit
# Processing Record 14 of Set 11 | anadyr
# Processing Record 15 of Set 11 | tuatapere
# Processing Record 16 of Set 11 | olot
# Processing Record 17 of Set 11 | abu kamal
# Processing Record 18 of Set 11 | fernley
# Processing Record 19 of Set 11 | adre
# Processing Record 20 of Set 11 | vilcun
# Processing Record 21 of Set 11 | sao domingos
# Processing Record 22 of Set 11 | abbeville
# Processing Record 23 of Set 11 | longkou
# Processing Record 24 of Set 11 | taoudenni
# Processing Record 25 of Set 11 | husavik
# Processing Record 26 of Set 11 | ust-nera
# Processing Record 27 of Set 11 | cockburn town
# Processing Record 28 of Set 11 | ulaanbaatar
# Processing Record 29 of Set 11 | marawi
# Processing Record 30 of Set 11 | camacha
# Processing Record 31 of Set 11 | barentu
# Processing Record 32 of Set 11 | orotukan
# Processing Record 33 of Set 11 | iskateley
# Processing Record 34 of Set 11 | pahrump
# Processing Record 35 of Set 11 | banjar
# Processing Record 36 of Set 11 | irituia
# Processing Record 37 of Set 11 | eureka
# Processing Record 38 of Set 11 | aklavik
# Processing Record 39 of Set 11 | yining
# Processing Record 40 of Set 11 | port lincoln
# Processing Record 41 of Set 11 | hammerfest
# Processing Record 42 of Set 11 | balikpapan
# Processing Record 43 of Set 11 | dukat
# Processing Record 44 of Set 11 | sao felix do xingu
# Processing Record 45 of Set 11 | ostrovnoy
# Processing Record 46 of Set 11 | aasiaat
# Processing Record 47 of Set 11 | surgut
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 11 | jalingo
# Processing Record 49 of Set 11 | beyneu
# Processing Record 50 of Set 11 | diffa
# Processing Record 0 of Set 12 | sola
# City not found. Skipping...
# Processing Record 1 of Set 12 | clinton
# Processing Record 2 of Set 12 | kawambwa
# Processing Record 3 of Set 12 | ulladulla
# Processing Record 4 of Set 12 | marzuq
# Processing Record 5 of Set 12 | ishigaki
# -----------------------------
# Data Retrieval Completed
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({'City': City,
                          'Cloudiness': Cloudiness,
                           'Country': Country,
                           'Date': Date,
                           'Humidity':Humidity,
                           'Lat':Lat,
                           'Lng': Lng,
                           'Max Temp': Max_Temp,
                           'Wind Speed': Wind_Speed
                          })
weather_df.count()
# Out:
# City          566
# Cloudiness    566
# Country       566
# Date          566
# Humidity      566
# Lat           566
# Lng           566
# Max Temp      566
# Wind Speed    566
# dtype: int64

# %%
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Sabang          82      PH  1561615905        93  13.80  121.11
# 1     Barrow          96      AR  1561615905        42 -38.31  -60.23
# 2    Ushuaia          75      AR  1561615906       100 -54.81  -68.31
# 3       Hilo          90      US  1561615681        74  19.71 -155.08
# 4  Inhambane          40      MZ  1561615906        88 -23.87   35.38
#
#    Max Temp  Wind Speed
# 0     77.81        7.90
# 1     47.93       14.25
# 2     28.40       24.16
# 3     80.60        9.17
# 4     68.00        2.33

# %%
#UTC time to local time
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.htmldf['timestamp'].dt.tz_localize('utc').dt.tz_convert('US/Central')
#EX:    pd.to_datetime(1490195805, unit='s') <---- Timestamp('2017-03-22 15:16:45')

weather_df['Date'] = pd.to_datetime(weather_df['Date'], unit='s')
weather_df_date.head()
# Out:
# 0   2019-06-27 06:11:45
# 1   2019-06-27 06:11:45
# 2   2019-06-27 06:11:46
# 3   2019-06-27 06:08:01
# 4   2019-06-27 06:11:46
# Name: Date, dtype: datetime64[ns]

# %%
#save to csv
weather_df.to_csv('output_data/weather_pd.csv', index = False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plot Latitude vs. Temperature
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Lng'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Max Temperature (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Max Temperature(F)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_MaxTemp", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plot Latitude vs. Humidity
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Humidity (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Humidity (%)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_Humidity", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plot Latitude vs. Cloudiness
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Cloudiness (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Cloudiness (%)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_Cloudiness", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plot Latitude vs. Wind Speed
fig,axl = plt.subplots()
axl.set_facecolor('white')
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], edgecolor = 'black', marker='o')
plt.grid (color='grey')
plt.title("City Latitude vs. Wind Speed (06/27/19)", fontsize=12)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Wind Speed (%)", fontsize=10)
# Save Figure as png
plt.savefig("output_data/Lat_WindSpeed", bbox_inches='tight')
plt.show()
